# %%
try:
    spark.stop()
except Exception:
    pass

from pyspark.sql import SparkSession

spark = (
    SparkSession.builder.appName("Iceberg via REST")
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions")
    .config("spark.sql.catalog.local", "org.apache.iceberg.spark.SparkCatalog")
    .config("spark.sql.catalog.local.type", "rest")
    .config("spark.sql.catalog.local.uri", "http://iceberg-rest:8181")
    .config("spark.sql.catalog.local.warehouse", "s3://lake/warehouse")
    .config("spark.sql.catalog.local.io-impl", "org.apache.iceberg.aws.s3.S3FileIO")
    .config("spark.sql.catalog.local.s3.endpoint", "http://minio:9000")
    .config("spark.sql.catalog.local.s3.path-style-access", "true")
    .config("spark.sql.catalog.local.s3.access-key-id", "admin")
    .config("spark.sql.catalog.local.s3.secret-access-key", "admin123")
    .config("spark.sql.catalog.local.s3.region", "us-east-1")
    .getOrCreate()
)

spark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       3 except Exception:
#       4     pass
# ----> 6 from pyspark.sql import SparkSession
#       8 spark = (
#       9     SparkSession.builder.appName("Iceberg via REST")
#      10     .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions")
#    (...)
#      21     .getOrCreate()
#      22 )
#      24 spark
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
spark.sql("SHOW NAMESPACES IN local").show(truncate=False)
# Out:
# +---------+
# |namespace|
# +---------+
# |raw      |
# |silver   |
# +---------+

# %%
spark.sql("SHOW TABLES IN local.raw").show(truncate=False)
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |raw      |avito    |false      |
# +---------+---------+-----------+

# %%
spark.sql("SHOW TABLES IN local.silver").show(truncate=False)
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |silver   |avito    |false      |
# +---------+---------+-----------+

# %%
tbl = "local.raw.avito"
spark.sql(f"SELECT COUNT(*) AS rows FROM {tbl}").show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 tbl = "local.raw.avito"
# ----> 2 spark.sql(f"SELECT COUNT(*) AS rows FROM {tbl}").show()
#
# NameError: name 'spark' is not defined

# %%
tbl_ = "local.silver.avito"
spark.sql(f"SELECT COUNT(*) AS rows FROM {tbl_}").show()
# Out:
# +----+
# |rows|
# +----+
# | 786|
# +----+

# %%
spark.sql("SELECT * FROM local.raw.avito LIMIT 1").show(truncate=False)
# Out:
# +--------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------+
# |id      |payload                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |ingest_ts              |
# +--------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------+
# |55105755|{"id": "55105755", "url": "https://www.avito.ma/fr/targa/villas_et_riads/Location_belle_Maison_55105755.htm", "error": null, "title": "Location belle Maison", "price_text": "2 500 DH", "breadcrumbs": "Home Icon Accueil > Tout le Maroc > Marrakech > Targa > Avito Immobilier > Locations Immobilières > Villas et Riads > Location belle Maison", "category": "Villas et Riads, à louer", "description": "Je met en location une belle Maison sous forme d'une ferme situé a 16 Km de Marrakech Route de Targa Douar Aarich, dans un environnement calme, Ensoleillé, et sécurisé. Elle se compose de : - Entrée spacieuse - 1 salon - 5 chambres - 2 salles de bains - grande terrasse - piscine - jardin NB: 2500 dhs la nuitée pour 3 chambres, minimum deux (2) nuitée 4000 dhs la nuitée pour 5 chambres, minimum deux (2) nuitée Location juste pour les familles.", "attributes": "{\"Chambres\": \"3\", \"Salle de bain\": \"2\", \"Nombre d'étage\": \"1\", \"Salons\": \"1\", \"Surface habitable\": \"2000\"}", "equipments": "3; 2; 1; 1; 2000; Balcon; Climatisation; Cuisine équipée; Jardin; Parking; Piscine", "seller_name": "Halim", "seller_type": "Particulier", "published_date": "il y a 4 heures", "image_urls": "https://content.avito.ma/classifieds/images/10121034468?t=images | https://content.avito.ma/classifieds/images/10121034472?t=images | https://content.avito.ma/classifieds/images/10121034469?t=images | https://content.avito.ma/classifieds/images/10121034471?t=images | https://content.avito.ma/classifieds/images/10121034466?t=images | https://content.avito.ma/classifieds/images/10121034467?t=images | https://content.avito.ma/classifieds/images/10121034470?t=images"}|2025-11-02 18:30:15.007|
# +--------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------+
